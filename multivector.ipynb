# %%
# !pip install -r requirements.txt
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain==0.2.12
# Out:
# Collecting langchain==0.2.12
#   Downloading langchain-0.2.12-py3-none-any.whl.metadata (7.1 kB)
# Collecting PyYAML>=5.3 (from langchain==0.2.12)
#   Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain==0.2.12)
#   Downloading SQLAlchemy-2.0.31-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain==0.2.12)
#   Downloading aiohttp-3.10.0-cp312-cp312-win_amd64.whl.metadata (7.8 kB)
# Collecting langchain-core<0.3.0,>=0.2.27 (from langchain==0.2.12)
#   Downloading langchain_core-0.2.28-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain==0.2.12)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.2.12)
#   Downloading langsmith-0.1.96-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2.0.0,>=1.26.0 (from langchain==0.2.12)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# Collecting pydantic<3,>=1 (from langchain==0.2.12)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      -------------------------------------  122.9/125.2 kB 3.5 MB/s eta 0:00:01
#      -------------------------------------- 125.2/125.2 kB 1.5 MB/s eta 0:00:00
# Collecting requests<3,>=2 (from langchain==0.2.12)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain==0.2.12)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.12)
#   Downloading aiohappyeyeballs-2.3.4-py3-none-any.whl.metadata (5.6 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.12)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.12)
#   Downloading attrs-24.1.0-py3-none-any.whl.metadata (14 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.12)
#   Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.12)
#   Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.12)
#   Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl.metadata (32 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.27->langchain==0.2.12)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in .\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.27->langchain==0.2.12) (24.1)
# Collecting typing-extensions>=4.7 (from langchain-core<0.3.0,>=0.2.27->langchain==0.2.12)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain==0.2.12)
#   Downloading orjson-3.10.6-cp312-none-win_amd64.whl.metadata (51 kB)
#      ---------------------------------------- 0.0/51.6 kB ? eta -:--:--
#      ---------------------------------------- 51.6/51.6 kB 2.6 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain==0.2.12)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic<3,>=1->langchain==0.2.12)
#   Downloading pydantic_core-2.20.1-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain==0.2.12)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain==0.2.12)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain==0.2.12)
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain==0.2.12)
#   Downloading certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain==0.2.12)
#   Downloading greenlet-3.0.3-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain==0.2.12)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Downloading langchain-0.2.12-py3-none-any.whl (990 kB)
#    ---------------------------------------- 0.0/990.6 kB ? eta -:--:--
#    ---- ----------------------------------- 112.6/990.6 kB 2.2 MB/s eta 0:00:01
#    ------- -------------------------------- 174.1/990.6 kB 2.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 297.0/990.6 kB 2.0 MB/s eta 0:00:01
#    --------------- ------------------------ 378.9/990.6 kB 1.8 MB/s eta 0:00:01
#    ------------------ --------------------- 460.8/990.6 kB 1.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 583.7/990.6 kB 1.9 MB/s eta 0:00:01
#    -------------------------- ------------- 665.6/990.6 kB 2.0 MB/s eta 0:00:01
#    ------------------------------- -------- 788.5/990.6 kB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 798.7/990.6 kB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 952.3/990.6 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 990.6/990.6 kB 1.9 MB/s eta 0:00:00
# Downloading aiohttp-3.10.0-cp312-cp312-win_amd64.whl (373 kB)
#    ---------------------------------------- 0.0/374.0 kB ? eta -:--:--
#    --------- ------------------------------ 92.2/374.0 kB 2.6 MB/s eta 0:00:01
#    --------------- ------------------------ 143.4/374.0 kB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 327.7/374.0 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 374.0/374.0 kB 2.3 MB/s eta 0:00:00
# Downloading langchain_core-0.2.28-py3-none-any.whl (379 kB)
#    ---------------------------------------- 0.0/379.9 kB ? eta -:--:--
#    ---------------- ----------------------- 153.6/379.9 kB 4.6 MB/s eta 0:00:01
#    ------------------------------ --------- 286.7/379.9 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 379.9/379.9 kB 3.0 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.96-py3-none-any.whl (140 kB)
#    ---------------------------------------- 0.0/140.1 kB ? eta -:--:--
#    -------------------------------------- - 133.1/140.1 kB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 140.1/140.1 kB 2.1 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.2/15.5 MB 3.5 MB/s eta 0:00:05
#     --------------------------------------- 0.3/15.5 MB 3.2 MB/s eta 0:00:05
#    - -------------------------------------- 0.4
MB 1.3 MB/s eta 0:00:04
#    --------------------------- ------------ 10.9/15.5 MB 1.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.0/15.5 MB 1.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.2/15.5 MB 1.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 11.3/15.5 MB 1.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 11.4/15.5 MB 1.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 11.5/15.5 MB 1.3 MB/s eta 0:00:04
#    ------------------------------ --------- 11.7/15.5 MB 1.3 MB/s eta 0:00:04
#    ------------------------------ --------- 11.8/15.5 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 12.0/15.5 MB 1.3 MB/s eta 0:00:03
#    ------------------------------- -------- 12.2/15.5 MB 1.3 MB/s eta 0:00:03
#    ------------------------------- -------- 12.3/15.5 MB 1.3 MB/s eta 0:00:03
#    -------------------------------- ------- 12.5/15.5 MB 1.3 MB/s eta 0:00:03
#    -------------------------------- ------- 12.7/15.5 MB 1.3 MB/s eta 0:00:03
#    -------------------------------- ------- 12.7/15.5 MB 1.3 MB/s eta 0:00:03
#    -------------------------------- ------- 12.7/15.5 MB 1.3 MB/s eta 0:00:03
#    --------------------------------- ------ 12.8/15.5 MB 1.3 MB/s eta 0:00:03
#    --------------------------------- ------ 12.8/15.5 MB 1.3 MB/s eta 0:00:03
#    --------------------------------- ------ 12.8/15.5 MB 1.3 MB/s eta 0:00:03
#    --------------------------------- ------ 12.9/15.5 MB 1.2 MB/s eta 0:00:03
#    --------------------------------- ------ 13.0/15.5 MB 1.2 MB/s eta 0:00:03
#    --------------------------------- ------ 13.1/15.5 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.2/15.5 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.3/15.5 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.5/15.5 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.7/15.5 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.8/15.5 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.9/15.5 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 14.1/15.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 14.5/15.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 14.6/15.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 14.8/15.5 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 15.0/15.5 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  15.1/15.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  15.3/15.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 1.8 MB/s eta 0:00:00
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ---------------------------------------- 0.0/423.9 kB ? eta -:--:--
#    ---------------- ----------------------- 174.1/423.9 kB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 307.2/423.9 kB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 389.1/423.9 kB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 423.9/423.9 kB 2.4 MB/s eta 0:00:00
# Downloading pydantic_core-2.20.1-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.9 MB 4.5 MB/s eta 0:00:01
#    --- ------------------------------------ 0.1/1.9 MB 1.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/1.9 MB 1.9 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/1.9 MB 2.4 MB/s eta 0:00:01
#    ------------ --------------------------- 0.6/1.9 MB 2.6 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.9 MB 2.6 MB/s eta 0:00:01
#    ------------------ --------------------- 0.9/1.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.0/1.9 MB 2.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.9 MB 2.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.4/1.9 MB 2.9 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/1.9 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 1.7/1.9 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 2.8 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl (138 kB)
#    ---------------------------------------- 0.0/138.7 kB ? eta -:--:--
#    -------------------------------------- - 133.1/138.7 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 138.7/138.7 kB 2.0 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 1.8 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.31-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.1 MB 5.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/2.1 MB 3.7 MB/s eta 0:00:01
#    -------- ------------------------------- 0.4/2.1 MB 3.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.1 MB 3.7 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 3.7 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.1 MB 3.7 MB/s eta 0:00:01
#    --------------------- ------------------ 1.1/2.1 MB 3.6 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.5/2.1 MB 3.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------ --- 1.9/2.1 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 2.0/2.1 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 3.2 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading aiohappyeyeballs-2.3.4-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading attrs-24.1.0-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.9 kB ? eta -:--:--
#    -------------------------------------- - 61.4/63.9 kB ? eta -:--:--
#    -------------------------------------- - 61.4/63.9 kB ? eta -:--:--
#    -------------------------------------- - 61.4/63.9 kB ? eta -:--:--
#    -------------------------------------- - 61.4/63.9 kB ? eta -:--:--
#    -------------------------------------- - 61.4/63.9 kB ? eta -:--:--
#    ---------------------------------------- 63.9/63.9 kB 229.2 kB/s eta 0:00:00
# Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/163.0 kB ? eta -:--:--
#    ------------------------------------- -- 153.6/163.0 kB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 163.0/163.0 kB 2.4 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB 1.9 MB/s eta 0:00:00
# Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
#    ---------------------------------------- 0.0/50.5 kB ? eta -:--:--
#    ---------------------------------------- 50.5/50.5 kB 1.3 MB/s eta 0:00:00
# Downloading greenlet-3.0.3-cp312-cp312-win_amd64.whl (293 kB)
#    ---------------------------------------- 0.0/293.6 kB ? eta -:--:--
#    -------------------- ------------------- 153.6/293.6 kB 4.5 MB/s eta 0:00:01
#    -------------------------- ------------- 194.6/293.6 kB 2.4 MB/s eta 0:00:01
#    --------------------------- ------------ 204.8/293.6 kB 1.8 MB/s eta 0:00:01
#    ------------------------------ --------- 225.3/293.6 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 256.0/293.6 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  286.7/293.6 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 293.6/293.6 kB 1.1 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ------------------ --------------------- 30.7/66.8 kB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 61.4/66.8 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 66.8/66.8 kB 725.6 kB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl (27 kB)
# Downloading orjson-3.10.6-cp312-none-win_amd64.whl (136 kB)
#    ---------------------------------------- 0.0/136.4 kB ? eta -:--:--
#    ---------------------------------------  133.1/136.4 kB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 136.4/136.4 kB 2.7 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.4 kB ? eta -:--:--
#    -------------------- ------------------- 61.4/121.4 kB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 112.6/121.4 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 121.4/121.4 kB 1.2 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl (76 kB)
#    ---------------------------------------- 0.0/76.4 kB ? eta -:--:--
#    ---------------------------------------- 76.4/76.4 kB 1.4 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: urllib3, typing-extensions, tenacity, PyYAML, orjson, numpy, multidict, jsonpointer, idna, greenlet, frozenlist, charset-normalizer, certifi, attrs, annotated-types, aiohappyeyeballs, yarl, SQLAlchemy, requests, pydantic-core, jsonpatch, aiosignal, pydantic, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.31 aiohappyeyeballs-2.3.4 aiohttp-3.10.0 aiosignal-1.3.1 annotated-types-0.7.0 attrs-24.1.0 certifi-2024.7.4 charset-normalizer-3.3.2 frozenlist-1.4.1 greenlet-3.0.3 idna-3.7 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.12 langchain-core-0.2.28 langchain-text-splitters-0.2.2 langsmith-0.1.96 multidict-6.0.5 numpy-1.26.4 orjson-3.10.6 pydantic-2.8.2 pydantic-core-2.20.1 requests-2.32.3 tenacity-8.5.0 typing-extensions-4.12.2 urllib3-2.2.2 yarl-1.9.4
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain-qdrant==0.1.3
# !pip install PyMuPDF==1.24.9
# Out:
# Collecting langchain-qdrant==0.1.3
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading langchain_qdrant-0.1.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in .\venv\lib\site-packages (from langchain-qdrant==0.1.3) (0.2.28)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\venv\lib\site-packages (from langchain-qdrant==0.1.3) (2.8.2)
# Collecting qdrant-client<2.0.0,>=1.10.1 (from langchain-qdrant==0.1.3)
#   Downloading qdrant_client-1.10.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: PyYAML>=5.3 in .\venv\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-qdrant==0.1.3) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in .\venv\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-qdrant==0.1.3) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in .\venv\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-qdrant==0.1.3) (0.1.96)
# Requirement already satisfied: packaging<25,>=23.2 in .\venv\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-qdrant==0.1.3) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in .\venv\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-qdrant==0.1.3) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in .\venv\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-qdrant==0.1.3) (4.12.2)
# Requirement already satisfied: annotated-types>=0.4.0 in .\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-qdrant==0.1.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in .\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-qdrant==0.1.3) (2.20.1)
# Collecting grpcio>=1.41.0 (from qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading grpcio-1.65.4-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting grpcio-tools>=1.41.0 (from qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading grpcio_tools-1.65.4-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting httpx>=0.20.0 (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: numpy>=1.26 in .\venv\lib\site-packages (from qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3) (1.26.4)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: urllib3<3,>=1.26.14 in .\venv\lib\site-packages (from qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3) (2.2.2)
# Collecting protobuf<6.0dev,>=5.26.1 (from grpcio-tools>=1.41.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading protobuf-5.27.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting setuptools (from grpcio-tools>=1.41.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Using cached setuptools-72.1.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting anyio (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi in .\venv\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3) (2024.7.4)
# Collecting httpcore==1.* (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in .\venv\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3) (3.7)
# Collecting sniffio (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading h2-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jsonpointer>=1.9 in .\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain-qdrant==0.1.3) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in .\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-qdrant==0.1.3) (3.10.6)
# Requirement already satisfied: requests<3,>=2 in .\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-qdrant==0.1.3) (2.32.3)
# Requirement already satisfied: pywin32>=226 in .\venv\lib\site-packages (from portalocker<3.0.0,>=2.7.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3) (306)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading hyperframe-6.0.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.10.1->langchain-qdrant==0.1.3)
#   Downloading hpack-4.0.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\venv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-qdrant==0.1.3) (3.3.2)
# Downloading langchain_qdrant-0.1.3-py3-none-any.whl (22 kB)
# Downloading qdrant_client-1.10.1-py3-none-any.whl (254 kB)
#    ---------------------------------------- 0.0/254.1 kB ? eta -:--:--
#    ------------ --------------------------- 81.9/254.1 kB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 204.8/254.1 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 254.1/254.1 kB 2.0 MB/s eta 0:00:00
# Downloading grpcio-1.65.4-cp312-cp312-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    - -------------------------------------- 0.1/4.1 MB 8.2 MB/s eta 0:00:01
#    --- ------------------------------------ 0.3/4.1 MB 3.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.6/4.1 MB 4.1 MB/s eta 0:00:01
#    ------- -------------------------------- 0.7/4.1 MB 3.9 MB/s eta 0:00:01
#    --------- ------------------------------ 0.9/4.1 MB 4.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.2/4.1 MB 4.1 MB/s eta 0:00:01
#    ------------ --------------------------- 1.3/4.1 MB 3.9 MB/s eta 0:00:01
#    ------------- -------------------------- 1.4/4.1 MB 3.8 MB/s eta 0:00:01
#    --------------- ------------------------ 1.6/4.1 MB 3.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.8/4.1 MB 3.8 MB/s eta 0:00:01
#    ------------------- -------------------- 2.0/4.1 MB 4.0 MB/s eta 0:00:01
#    --------------------- ------------------ 2.2/4.1 MB 4.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.4/4.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.5/4.1 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 2.7/4.1 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 2.9/4.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.0/4.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 3.3/4.1 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 3.5/4.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 3.9/4.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  4.1/4.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 3.8 MB/s eta 0:00:00
# Downloading grpcio_tools-1.65.4-cp312-cp312-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.2/1.1 MB 5.3 MB/s eta 0:00:01
#    ------------ --------------------------- 0.3/1.1 MB 4.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.6/1.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 0.9/1.1 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 5.2 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 4.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB 4.5 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
#    ---------------------------------------- 57.5/57.5 kB 3.0 MB/s eta 0:00:00
# Downloading protobuf-5.27.3-cp310-abi3-win_amd64.whl (426 kB)
#    ---------------------------------------- 0.0/426.9 kB ? eta -:--:--
#    -------------------- ------------------ 225.3/426.9 kB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 426.9/426.9 kB 6.6 MB/s eta 0:00:00
# Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ---------------------------------------- 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached setuptools-72.1.0-py3-none-any.whl (2.3 MB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Installing collected packages: sniffio, setuptools, protobuf, portalocker, hyperframe, hpack, h11, grpcio, httpcore, h2, grpcio-tools, anyio, httpx, qdrant-client, langchain-qdrant
# Successfully installed anyio-4.4.0 grpcio-1.65.4 grpcio-tools-1.65.4 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-1.0.5 httpx-0.27.0 hyperframe-6.0.1 langchain-qdrant-0.1.3 portalocker-2.10.1 protobuf-5.27.3 qdrant-client-1.10.1 setuptools-72.1.0 sniffio-1.3.1
# Collecting PyMuPDF==1.24.9
#   Downloading PyMuPDF-1.24.9-cp312-none-win_amd64.whl.metadata (3.4 kB)
# Collecting PyMuPDFb==1.24.9 (from PyMuPDF==1.24.9)
#   Downloading PyMuPDFb-1.24.9-py3-none-win_amd64.whl.metadata (1.4 kB)
# Downloading PyMuPDF-1.24.9-cp312-none-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB 162.5 kB/s eta 0:00:20
#    ---------------------------------------- 0.0/3.2 MB 163.8 kB/s eta 0:00:20
#     --------------------------------------- 0.1/3.2 MB 326.1 kB/s eta 0:00:10
#    - -------------------------------------- 0.1/3.2 MB 502.0 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/3.2 MB 502.0 kB/s eta 0:00:07
#    --- ------------------------------------ 0.2/3.2 MB 835.2 kB/s eta 0:00:04
#    --- ------------------------------------ 0.2/3.2 MB 835.2 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.3/3.2 MB 846.5 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.3/3.2 MB 846.5 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.4/3.2 MB 737.3 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.5/3.2 MB 893.0 kB/s eta 0:00:04
#    ------- -------------------------------- 0.6/3.2 MB 1.0 MB/s eta 0:00:03
#    -------- ------------------------------- 0.7/3.2 MB 1.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 0.9/3.2 MB 1.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.9/3.2 MB 1.3 MB/s eta 0:00:02
#    -------------- ------------------------- 1.2/3.2 MB 1.6 MB/s eta 0:00:02
#    ------------------ --------------------- 1.5/3.2 MB 1.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.9/3.2 MB 2.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.3/3.2 MB 2.5 MB/s eta 0:00:01
#    ------------------------------ --------- 2.5/3.2 MB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 2.6/3.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.8/3.2 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 2.9/3.2 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 3.1/3.2 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  3.2/3.2 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 2.7 MB/s eta 0:00:00
# Downloading PyMuPDFb-1.24.9-py3-none-win_amd64.whl (13.2 MB)
#    ---------------------------------------- 0.0/13.2 MB ? eta -:--:--
#    - -------------------------------------- 0.4/13.2 MB 13.2 MB/s eta 0:00:01
#    - -------------------------------------- 0.6/13.2 MB 9.2 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/13.2 MB 6.5 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/13.2 MB 5.8 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/13.2 MB 5.8 MB/s eta 0:00:03
#    --- ------------------------------------ 1.2/13.2 MB 4.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/13.2 MB 5.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/13.2 MB 4.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/13.2 MB 4.4 MB/s eta 0:00:03
#    ------ --------------------------------- 2.2/13.2 MB 4.9 MB/s eta 0:00:03
#    ------- -------------------------------- 2.6/13.2 MB 5.1 MB/s eta 0:00:03
#    --------- ------------------------------ 3.0/13.2 MB 5.5 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/13.2 MB 5.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.5/13.2 MB 5.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.9/13.2 MB 5.8 MB/s eta 0:00:02
#    ------------- -------------------------- 4.4/13.2 MB 6.1 MB/s eta 0:00:02
#    -------------- ------------------------- 4.8/13.2 MB 6.3 MB/s eta 0:00:02
#    --------------- ------------------------ 5.3/13.2 MB 6.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.8/13.2 MB 6.6 MB/s eta 0:00:02
#    ------------------- -------------------- 6.3/13.2 MB 6.8 MB/s eta 0:00:02
#    -------------------- ------------------- 6.8/13.2 MB 7.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.3/13.2 MB 7.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.5/13.2 MB 7.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.9/13.2 MB 7.2 MB/s eta 0:00:01
#    ------------------------ --------------- 8.2/13.2 MB 7.2 MB/s eta 0:00:01
#    ------------------------- -------------- 8.4/13.2 MB 7.0 MB/s eta 0:00:01
#    -------------------------- ------------- 8.6/13.2 MB 6.9 MB/s eta 0:00:01
#    --------------------------- ------------ 8.9/13.2 MB 6.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.3/13.2 MB 6.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.6/13.2 MB 6.9 MB/s eta 0:00:01
#    ------------------------------ --------- 9.9/13.2 MB 6.9 MB/s eta 0:00:01
#    ------------------------------ --------- 10.2/13.2 MB 7.0 MB/s eta 0:00:01
#    ------------------------------- -------- 10.4/13.2 MB 6.8 MB/s eta 0:00:01
#    -------------------------------- ------- 10.8/13.2 MB 6.8 MB/s eta 0:00:01
#    -------------------------------- ------- 10.9/13.2 MB 6.9 MB/s eta 0:00:01
#    --------------------------------- ------ 11.1/13.2 MB 6.7 MB/s eta 0:00:01
#    --------------------------------- ------ 11.2/13.2 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.5/13.2 MB 6.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.7/13.2 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------ --- 12.2/13.2 MB 7.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.7/13.2 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.2 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  13.2/13.2 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  13.2/13.2 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  13.2/13.2 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  13.2/13.2 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 13.2/13.2 MB 6.4 MB/s eta 0:00:00
# Installing collected packages: PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.24.9 PyMuPDFb-1.24.9
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading matplotlib-3.9.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp312-cp312-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/165.9 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 2.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.23 in .\venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in .\venv\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in .\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.1-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB 1.4 MB/s eta 0:00:06
#     --------------------------------------- 0.1/8.0 MB 1.3 MB/s eta 0:00:06
#     --------------------------------------- 0.2/8.0 MB 1.6 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/8.0 MB 1.6 MB/s eta 0:00:05
#    -- ------------------------------------- 0.4/8.0 MB 2.1 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/8.0 MB 3.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.8/8.0 MB 3.1 MB/s eta 0:00:03
#    ------ --------------------------------- 1.2/8.0 MB 3.7 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/8.0 MB 4.4 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.0 MB 4.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.2/8.0 MB 4.9 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/8.0 MB 5.0 MB/s eta 0:00:02
#    ------------ --------------------------- 2.5/8.0 MB 4.9 MB/s eta 0:00:02
#    ------------- -------------------------- 2.7/8.0 MB 4.8 MB/s eta 0:00:02
#    ------------- -------------------------- 2.7/8.0 MB 4.7 MB/s eta 0:00:02
#    -------------- ------------------------- 3.0/8.0 MB 4.6 MB/s eta 0:00:02
#    -------------- ------------------------- 3.0/8.0 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.0 MB 4.1 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.0 MB 4.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.3/8.0 MB 4.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.4/8.0 MB 4.0 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.0 MB 4.1 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.0 MB 4.2 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.0 MB 4.4 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/8.0 MB 4.6 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.6/8.0 MB 4.9 MB/s eta 0:00:01
#    ------------------------------ --------- 6.1/8.0 MB 5.0 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/8.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.0/8.0 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  7.8/8.0 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.0 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 5.5 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    --------------------------------------- 189.9/189.9 kB 11.2 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------- ---------------------------- 0.6/2.2 MB 10.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.2 MB 11.0 MB/s eta 0:00:01
#    ------------------------- -------------- 1.4/2.2 MB 11.0 MB/s eta 0:00:01
#    --------------------------------- ------ 1.9/2.2 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 9.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB ? eta 0:00:00
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.6 MB 22.5 MB/s eta 0:00:01
#    --------- ------------------------------ 0.6/2.6 MB 7.9 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.6 MB 7.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.1/2.6 MB 7.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.1/2.6 MB 6.6 MB/s eta 0:00:01
#    ------------------- -------------------- 1.2/2.6 MB 5.6 MB/s eta 0:00:01
#    --------------------- ------------------ 1.4/2.6 MB 4.9 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 4.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.6 MB 4.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.9/2.6 MB 4.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.9/2.6 MB 4.6 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.6 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.6 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.6 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 3.5 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2

# %%
pip install unstructured
# Out:
# Collecting unstructuredNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading unstructured-0.15.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: chardet in .\venv\lib\site-packages (from unstructured) (5.2.0)
# Collecting filetype (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in .\venv\lib\site-packages (from unstructured) (5.2.2)
# Collecting nltk (from unstructured)
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting tabulate (from unstructured)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: requests in .\venv\lib\site-packages (from unstructured) (2.32.3)
# Collecting beautifulsoup4 (from unstructured)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting dataclasses-json (from unstructured)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2024.4.27-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ----------- -------------------------- 307.2/981.5 kB 9.6 MB/s eta 0:00:01
#      ------------------------ ------------- 624.6/981.5 kB 7.9 MB/s eta 0:00:01
#      -------------------------------------  972.8/981.5 kB 8.8 MB/s eta 0:00:01
#      -------------------------------------  972.8/981.5 kB 8.8 MB/s eta 0:00:01
#      -------------------------------------- 981.5/981.5 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy<2 in .\venv\lib\site-packages (from unstructured) (1.26.4)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.9.5-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in .\venv\lib\site-packages (from unstructured) (4.12.2)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.25.1-py3-none-any.whl.metadata (13 kB)
# Collecting wrapt (from unstructured)
#   Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting tqdm (from unstructured)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: psutil in .\venv\lib\site-packages (from unstructured) (6.0.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->unstructured)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured)
#   Downloading marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: six in .\venv\lib\site-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: click in .\venv\lib\site-packages (from nltk->unstructured) (8.1.7)
# Collecting joblib (from nltk->unstructured)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk->unstructured)
#   Downloading regex-2024.7.24-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 41.5/41.5 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in .\venv\lib\site-packages (from requests->unstructured) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\lib\site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\venv\lib\site-packages (from requests->unstructured) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in .\venv\lib\site-packages (from requests->unstructured) (2024.7.4)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from tqdm->unstructured) (0.4.6)
# Collecting deepdiff>=6.0 (from unstructured-client->unstructured)
#   Downloading deepdiff-7.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx>=0.27.0 in .\venv\lib\site-packages (from unstructured-client->unstructured) (0.27.0)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client->unstructured)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Collecting mypy-extensions>=1.0.0 (from unstructured-client->unstructured)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in .\venv\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: packaging>=23.1 in .\venv\lib\site-packages (from unstructured-client->unstructured) (24.1)
# Collecting pypdf>=4.0 (from unstructured-client->unstructured)
#   Using cached pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\lib\site-packages (from unstructured-client->unstructured) (2.9.0.post0)
# Collecting requests-toolbelt>=1.0.0 (from unstructured-client->unstructured)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting ordered-set<4.2.0,>=4.1.0 (from deepdiff>=6.0->unstructured-client->unstructured)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: anyio in .\venv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.4.0)
# Requirement already satisfied: httpcore==1.* in .\venv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.5)
# Requirement already satisfied: sniffio in .\venv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in .\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Downloading unstructured-0.15.0-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------- ------------------------------- 0.4/2.1 MB 13.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.1 MB 7.2 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 8.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.5/2.1 MB 8.9 MB/s eta 0:00:01
#    -------------------------------------- - 2.0/2.1 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.4 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    ---------------------------------------- 147.9/147.9 kB 9.2 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ---------------------------------------- 0.0/431.4 kB ? eta -:--:--
#    ----------------------------- --------- 327.7/431.4 kB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 431.4/431.4 kB 6.8 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 16.2 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.5 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.5 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.4 MB/s eta 0:00:00
# Downloading python_iso639-2024.4.27-py3-none-any.whl (274 kB)
#    ---------------------------------------- 0.0/274.7 kB ? eta -:--:--
#    ----------------------------- ---------- 204.8/274.7 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 274.7/274.7 kB 3.3 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading rapidfuzz-3.9.5-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB 5.7 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.6 MB 5.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.7/1.6 MB 5.7 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.6 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.4/1.6 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.5 MB/s eta 0:00:00
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.4 kB ? eta -:--:--
#    ---------------------------------------- 78.4/78.4 kB 2.1 MB/s eta 0:00:00
# Downloading unstructured_client-0.25.1-py3-none-any.whl (43 kB)
#    ---------------------------------------- 0.0/43.5 kB ? eta -:--:--
#    ---------------------------------------- 43.5/43.5 kB 2.2 MB/s eta 0:00:00
# Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Downloading deepdiff-7.0.1-py3-none-any.whl (80 kB)
#    ---------------------------------------- 0.0/80.8 kB ? eta -:--:--
#    ---------------------------------------- 80.8/80.8 kB 2.2 MB/s eta 0:00:00
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.2 kB ? eta -:--:--
#    ---------------------------------------- 49.2/49.2 kB 1.3 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
#    ---------------------------------------- 0.0/295.8 kB ? eta -:--:--
#    -------------------------------------- - 286.7/295.8 kB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 295.8/295.8 kB 6.1 MB/s eta 0:00:00
# Downloading regex-2024.7.24-cp312-cp312-win_amd64.whl (269 kB)
#    ---------------------------------------- 0.0/269.2 kB ? eta -:--:--
#    ---------------------------------------- 269.2/269.2 kB 8.1 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB 2.9 MB/s eta 0:00:00
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    ---------------------------------------  297.0/301.8 kB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 301.8/301.8 kB 4.6 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (pyproject.toml): started
#   Building wheel for langdetect (pyproject.toml): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993250 sha256=ee77d459ef82fcad7e28a6a9429f169176585f04c07e430a4e5fcffd6ce937c4
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: filetype, wrapt, tqdm, tabulate, soupsieve, regex, rapidfuzz, python-magic, python-iso639, pypdf, ordered-set, mypy-extensions, marshmallow, langdetect, jsonpath-python, joblib, emoji, backoff, typing-inspect, requests-toolbelt, nltk, deepdiff, beautifulsoup4, dataclasses-json, unstructured-client, unstructured
# Successfully installed backoff-2.2.1 beautifulsoup4-4.12.3 dataclasses-json-0.6.7 deepdiff-7.0.1 emoji-2.12.1 filetype-1.2.0 joblib-1.4.2 jsonpath-python-1.0.6 langdetect-1.0.9 marshmallow-3.21.3 mypy-extensions-1.0.0 nltk-3.8.1 ordered-set-4.1.0 pypdf-4.3.1 python-iso639-2024.4.27 python-magic-0.4.27 rapidfuzz-3.9.5 regex-2024.7.24 requests-toolbelt-1.0.0 soupsieve-2.5 tabulate-0.9.0 tqdm-4.66.5 typing-inspect-0.9.0 unstructured-0.15.0 unstructured-client-0.25.1 wrapt-1.16.0

# %%
pip install pytesseract
# Out:
# Collecting pytesseractNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pytesseract-0.3.10-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in .\venv\lib\site-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in .\venv\lib\site-packages (from pytesseract) (10.4.0)
# Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in .\venv\lib\site-packages (10.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_qdrant import QdrantVectorStore
from langchain.retrievers.multi_vector import MultiVectorRetriever
import fitz  # import PyMuPDF

# %%
# !pip install "unstructured[pdf]"
# Out:
# Requirement already satisfied: unstructured[pdf] in .\venv\lib\site-packages (0.15.0)
# Requirement already satisfied: chardet in .\venv\lib\site-packages (from unstructured[pdf]) (5.2.0)
# Requirement already satisfied: filetype in .\venv\lib\site-packages (from unstructured[pdf]) (1.2.0)
# Requirement already satisfied: python-magic in .\venv\lib\site-packages (from unstructured[pdf]) (0.4.27)
# Requirement already satisfied: lxml in .\venv\lib\site-packages (from unstructured[pdf]) (5.2.2)
# Requirement already satisfied: nltk in .\venv\lib\site-packages (from unstructured[pdf]) (3.8.1)
# Requirement already satisfied: tabulate in .\venv\lib\site-packages (from unstructured[pdf]) (0.9.0)
# Requirement already satisfied: requests in .\venv\lib\site-packages (from unstructured[pdf]) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in .\venv\lib\site-packages (from unstructured[pdf]) (4.12.3)
# Requirement already satisfied: emoji in .\venv\lib\site-packages (from unstructured[pdf]) (2.12.1)
# Requirement already satisfied: dataclasses-json in .\venv\lib\site-packages (from unstructured[pdf]) (0.6.7)
# Requirement already satisfied: python-iso639 in .\venv\lib\site-packages (from unstructured[pdf]) (2024.4.27)
# Requirement already satisfied: langdetect in .\venv\lib\site-packages (from unstructured[pdf]) (1.0.9)
# Requirement already satisfied: numpy<2 in .\venv\lib\site-packages (from unstructured[pdf]) (1.26.4)
# Requirement already satisfied: rapidfuzz in .\venv\lib\site-packages (from unstructured[pdf]) (3.9.5)
# Requirement already satisfied: backoff in .\venv\lib\site-packages (from unstructured[pdf]) (2.2.1)
# Requirement already satisfied: typing-extensions in .\venv\lib\site-packages (from unstructured[pdf]) (4.12.2)
# Requirement already satisfied: unstructured-client in .\venv\lib\site-packages (from unstructured[pdf]) (0.25.1)
# Requirement already satisfied: wrapt in .\venv\lib\site-packages (from unstructured[pdf]) (1.16.0)
# Requirement already satisfied: tqdm in .\venv\lib\site-packages (from unstructured[pdf]) (4.64.0)
# Requirement already satisfied: psutil in .\venv\lib\site-packages (from unstructured[pdf]) (6.0.0)
# Collecting onnx (from unstructured[pdf])
#   Downloading onnx-1.16.2-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting pdf2image (from unstructured[pdf])
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pdfminer.six in .\venv\lib\site-packages (from unstructured[pdf]) (20240706)
# Collecting pikepdf (from unstructured[pdf])
#   Downloading pikepdf-9.1.0-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: pillow-heif in .\venv\lib\site-packages (from unstructured[pdf]) (0.18.0)
# Requirement already satisfied: pypdf in .\venv\lib\site-packages (from unstructured[pdf]) (4.3.1)
# Requirement already satisfied: pytesseract in .\venv\lib\site-packages (from unstructured[pdf]) (0.3.10)
# Collecting google-cloud-vision (from unstructured[pdf])
#   Downloading google_cloud_vision-3.7.4-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting effdet (from unstructured[pdf])
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting unstructured-inference==0.7.36 (from unstructured[pdf])
#   Downloading unstructured_inference-0.7.36-py3-none-any.whl.metadata (5.9 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[pdf])
#   Downloading unstructured.pytesseract-0.3.12-py3-none-any.whl.metadata (11 kB)
# Collecting layoutparser (from unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading layoutparser-0.3.4-py3-none-any.whl.metadata (7.7 kB)
# Collecting python-multipart (from unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: huggingface-hub in .\venv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (0.24.5)
# Collecting opencv-python!=4.7.0.68 (from unstructured-inference==0.7.36->unstructured[pdf])
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting onnxruntime>=1.17.0 (from unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading onnxruntime-1.18.1-cp312-cp312-win_amd64.whl.metadata (4.5 kB)
# Requirement already satisfied: matplotlib in .\venv\lib\site-packages (from unstructured-inference==0.7.36->unstructured[pdf]) (3.9.1)
# Collecting torch (from unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading torch-2.4.0-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting timm (from unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading timm-1.0.8-py3-none-any.whl.metadata (53 kB)
#      ---------------------------------------- 0.0/53.8 kB ? eta -:--:--
#      ---------------------------------------- 53.8/53.8 kB 1.4 MB/s eta 0:00:00
# Collecting transformers>=4.25.1 (from unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading transformers-4.43.3-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.7 kB ? eta -:--:--
#      ---------------------------------------- 43.7/43.7 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in .\venv\lib\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in .\venv\lib\site-packages (from unstructured.pytesseract>=0.3.12->unstructured[pdf]) (10.4.0)
# Requirement already satisfied: soupsieve>1.2 in .\venv\lib\site-packages (from beautifulsoup4->unstructured[pdf]) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\venv\lib\site-packages (from dataclasses-json->unstructured[pdf]) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in .\venv\lib\site-packages (from dataclasses-json->unstructured[pdf]) (0.9.0)
# Collecting torchvision (from effdet->unstructured[pdf])
#   Downloading torchvision-0.19.0-1-cp312-cp312-win_amd64.whl.metadata (6.1 kB)
# Collecting pycocotools>=2.0.2 (from effdet->unstructured[pdf])
#   Downloading pycocotools-2.0.8-cp312-cp312-win_amd64.whl.metadata (1.1 kB)
# Collecting omegaconf>=2.0 (from effdet->unstructured[pdf])
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf])
#   Downloading google_api_core-2.19.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 (from google-cloud-vision->unstructured[pdf])
#   Downloading google_auth-2.32.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-cloud-vision->unstructured[pdf])
#   Downloading proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in .\venv\lib\site-packages (from google-cloud-vision->unstructured[pdf]) (5.27.3)
# Requirement already satisfied: six in .\venv\lib\site-packages (from langdetect->unstructured[pdf]) (1.16.0)
# Requirement already satisfied: click in .\venv\lib\site-packages (from nltk->unstructured[pdf]) (8.1.7)
# Requirement already satisfied: joblib in .\venv\lib\site-packages (from nltk->unstructured[pdf]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in .\venv\lib\site-packages (from nltk->unstructured[pdf]) (2024.7.24)
# Requirement already satisfied: charset-normalizer>=2.0.0 in .\venv\lib\site-packages (from pdfminer.six->unstructured[pdf]) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in .\venv\lib\site-packages (from pdfminer.six->unstructured[pdf]) (43.0.0)
# Collecting Deprecated (from pikepdf->unstructured[pdf])
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\lib\site-packages (from requests->unstructured[pdf]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\venv\lib\site-packages (from requests->unstructured[pdf]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in .\venv\lib\site-packages (from requests->unstructured[pdf]) (2024.7.4)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from tqdm->unstructured[pdf]) (0.4.6)
# Requirement already satisfied: deepdiff>=6.0 in .\venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (7.0.1)
# Requirement already satisfied: httpx>=0.27.0 in .\venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (0.27.0)
# Requirement already satisfied: jsonpath-python>=1.0.6 in .\venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in .\venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in .\venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (2.9.0.post0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\venv\lib\site-packages (from unstructured-client->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in .\venv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (1.16.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in .\venv\lib\site-packages (from deepdiff>=6.0->unstructured-client->unstructured[pdf]) (4.1.0)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf])
#   Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in .\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]) (1.65.4)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf])
#   Downloading grpcio_status-1.65.4-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf])
#   Downloading cachetools-5.4.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf])
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf])
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: anyio in .\venv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (4.4.0)
# Requirement already satisfied: httpcore==1.* in .\venv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.0.5)
# Requirement already satisfied: sniffio in .\venv\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured[pdf]) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in .\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured[pdf]) (0.14.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->unstructured[pdf])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ---------------------------------------- 0.0/117.0 kB ? eta -:--:--
#      ------------------------------------ - 112.6/117.0 kB 6.4 MB/s eta 0:00:01
#      -------------------------------------- 117.0/117.0 kB 2.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: PyYAML>=5.1.0 in .\venv\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]) (6.0.1)
# Collecting coloredlogs (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting sympy (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: contourpy>=1.0.1 in .\venv\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in .\venv\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\venv\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\venv\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in .\venv\lib\site-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[pdf]) (3.1.2)
# Collecting safetensors (from timm->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading safetensors-0.4.3-cp312-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: filelock in .\venv\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[pdf]) (3.15.4)
# Requirement already satisfied: networkx in .\venv\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[pdf]) (3.3)
# Collecting jinja2 (from torch->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: fsspec in .\venv\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[pdf]) (2024.6.1)
# Requirement already satisfied: setuptools in .\venv\lib\site-packages (from torch->unstructured-inference==0.7.36->unstructured[pdf]) (72.1.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers>=4.25.1->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading tokenizers-0.19.1-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting scipy (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading scipy-1.14.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in .\venv\lib\site-packages (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (2.2.2)
# Collecting iopath (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ---------------------------------------- 0.0/42.2 kB ? eta -:--:--
#      ---------------------------------------- 42.2/42.2 kB 2.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pdfplumber (from layoutparser->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading pdfplumber-0.11.2-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.1 kB ? eta -:--:--
#      ---------------------------------------- 40.1/40.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in .\venv\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]) (2.22)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf])
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: portalocker in .\venv\lib\site-packages (from iopath->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (2.10.1)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: pytz>=2020.1 in .\venv\lib\site-packages (from pandas->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in .\venv\lib\site-packages (from pandas->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (2024.1)
# Collecting pdfminer.six (from unstructured[pdf])
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading pypdfium2-4.30.0-py3-none-win_amd64.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.5 kB ? eta -:--:--
#      --------------------------------- ------ 41.0/48.5 kB ? eta -:--:--
#      -------------------------------------- 48.5/48.5 kB 490.7 kB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[pdf])
#   Downloading pyreadline3-3.4.1-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pywin32>=226 in .\venv\lib\site-packages (from portalocker->iopath->layoutparser->unstructured-inference==0.7.36->unstructured[pdf]) (306)
# Downloading unstructured_inference-0.7.36-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.4 kB ? eta -:--:--
#    ---------------------------------------- 56.4/56.4 kB 1.5 MB/s eta 0:00:00
# Downloading unstructured.pytesseract-0.3.12-py3-none-any.whl (14 kB)
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.5 kB ? eta -:--:--
#    ------------------------------------ --- 102.4/112.5 kB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 102.4/112.5 kB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 102.4/112.5 kB 3.0 MB/s eta 0:00:01
#    -------------------------------------- 112.5/112.5 kB 544.0 kB/s eta 0:00:00
# Downloading google_cloud_vision-3.7.4-py2.py3-none-any.whl (467 kB)
#    ---------------------------------------- 0.0/467.5 kB ? eta -:--:--
#    -------------- ------------------------- 174.1/467.5 kB 5.3 MB/s eta 0:00:01
#    --------------------------- ------------ 317.4/467.5 kB 5.0 MB/s eta 0:00:01
#    -------------------------------- ------- 378.9/467.5 kB 3.4 MB/s eta 0:00:01
#    -------------------------------- ------- 378.9/467.5 kB 3.4 MB/s eta 0:00:01
#    -------------------------------- ------- 378.9/467.5 kB 3.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 409.6/467.5 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  460.8/467.5 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 467.5/467.5 kB 1.2 MB/s eta 0:00:00
# Downloading onnx-1.16.2-cp312-cp312-win_amd64.whl (14.4 MB)
#    ---------------------------------------- 0.0/14.4 MB ? eta -:--:--
#     --------------------------------------- 0.2/14.4 MB 5.9 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/14.4 MB 3.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.7/14.4 MB 4.7 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/14.4 MB 4.5 MB/s eta 0:00:04
#    -- ------------------------------------- 0.9/14.4 MB 4.0 MB/s eta 0:00:04
#    -- ------------------------------------- 1.1/14.4 MB 3.8 MB/s eta 0:00:04
#    --- ------------------------------------ 1.2/14.4 MB 3.7 MB/s eta 0:00:04
#    --- ------------------------------------ 1.4/14.4 MB 3.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.5/14.4 MB 3.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/14.4 MB 3.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.8/14.4 MB 3.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.9/14.4 MB 3.3 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.1/14.4 MB 3.2 MB/s eta 0:00:04
#    ------ --------------------------------- 2.3/14.4 MB 3.4 MB/s eta 0:00:04
#    ------ --------------------------------- 2.5/14.4 MB 3.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.6/14.4 MB 3.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.6/14.4 MB 3.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.7/14.4 MB 3.0 MB/s eta 0:00:04
#    -------- ------------------------------- 3.0/14.4 MB 3.1 MB/s eta 0:00:04
#    -------- ------------------------------- 3.1/14.4 MB 3.1 MB/s eta 0:00:04
#    --------- ------------------------------ 3.3/14.4 MB 3.1 MB/s eta 0:00:04
#    --------- ------------------------------ 3.4/14.4 MB 3.1 MB/s eta 0:00:04
#    --------- ------------------------------ 3.5/14.4 MB 3.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.6/14.4 MB 3.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.7/14.4 MB 3.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.8/14.4 MB 2.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.9/14.4 MB 2.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.9/14.4 MB 2.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.1/14.4 MB 2.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 4
5 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.8/6.2 MB 1.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.8/6.2 MB 1.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.8/6.2 MB 1.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 0.8/6.2 MB 1.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.8/6.2 MB 1.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.9/6.2 MB 1.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.9/6.2 MB 1.4 MB/s eta 0:00:04
#    ------ --------------------------------- 1.0/6.2 MB 1.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.1/6.2 MB 1.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.1/6.2 MB 1.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.1/6.2 MB 1.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.1/6.2 MB 1.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.1/6.2 MB 1.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.1/6.2 MB 1.5 MB/s eta 0:00:04
#    -------- ------------------------------- 1.2/6.2 MB 1.3 MB/s eta 0:00:04
#    -------- ------------------------------- 1.4/6.2 MB 1.3 MB/s eta 0:00:04
#    --------- ------------------------------ 1.4/6.2 MB 1.3 MB/s eta 0:00:04
#    --------- ------------------------------ 1.5/6.2 MB 1.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.6/6.2 MB 1.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.7/6.2 MB 1.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.8/6.2 MB 1.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.8/6.2 MB 1.4 MB/s eta 0:00:04
#    ------------ --------------------------- 1.9/6.2 MB 1.4 MB/s eta 0:00:04
#    ------------- -------------------------- 2.0/6.2 MB 1.5 MB/s eta 0:00:03
#    ------------- -------------------------- 2.1/6.2 MB 1.4 MB/s eta 0:00:03
#    ------------- -------------------------- 2.1/6.2 MB 1.5 MB/s eta 0:00:03
#    -------------- ------------------------- 2.2/6.2 MB 1.4 MB/s eta 0:00:03
#    -------------- ------------------------- 2.2/6.2 MB 1.4 MB/s eta 0:00:03
#    -------------- ------------------------- 2.3/6.2 MB 1.4 MB/s eta 0:00:03
#    -------------- ------------------------- 2.3/6.2 MB 1.4 MB/s eta 0:00:03
#    -------------- ------------------------- 2.3/6.2 MB 1.4 MB/s eta 0:00:03
#    -------------- ------------------------- 2.3/6.2 MB 1.3 MB/s eta 0:00:03
#    -------------- ------------------------- 2.3/6.2 MB 1.3 MB/s eta 0:00:03
#    -------------- ------------------------- 2.3/6.2 MB 1.3 MB/s eta 0:00:03
#    --------------- ------------------------ 2.3/6.2 MB 1.2 MB/s eta 0:00:04
#    --------------- ------------------------ 2.4/6.2 MB 1.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.5/6.2 MB 1.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.6/6.2 MB 1.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.6/6.2 MB 1.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 2.7/6.2 MB 1.2 MB/s eta 0:00:03
#    ------------------ --------------------- 2.8/6.2 MB 1.3 MB/s eta 0:00:03
#    ------------------ --------------------- 2.9/6.2 MB 1.3 MB/s eta 0:00:03
#    ------------------- -------------------- 3.0/6.2 MB 1.3 MB/s eta 0:00:03
#    ------------------- -------------------- 3.0/6.2 MB 1.3 MB/s eta 0:00:03
#    -------------------- ------------------- 3.2/6.2 MB 1.3 MB/s eta 0:00:03
#    -------------------- ------------------- 3.2/6.2 MB 1.3 MB/s eta 0:00:03
#    --------------------- ------------------ 3.3/6.2 MB 1.3 MB/s eta 0:00:03
#    --------------------- ------------------ 3.4/6.2 MB 1.3 MB/s eta 0:00:03
#    --------------------- ------------------ 3.4/6.2 MB 1.3 MB/s eta 0:00:03
#    --------------------- ------------------ 3.4/6.2 MB 1.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.5/6.2 MB 1.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 3.6/6.2 MB 1.3 MB/s eta 0:00:02
#    ------------------------ --------------- 3.8/6.2 MB 1.4 MB/s eta 0:00:02
#    ------------------------ --------------- 3.9/6.2 MB 1.4 MB/s eta 0:00:02
#    ------------------------- -------------- 4.0/6.2 MB 1.4 MB/s eta 0:00:02
#    --------------------------- ------------ 4.2/6.2 MB 1.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.4/6.2 MB 1.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 4.6/6.2 MB 1.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 4.6/6.2 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 4.7/6.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------ --------- 4.8/6.2 MB 1.5 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.2 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 5.1/6.2 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.3/6.2 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.4/6.2 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.4/6.2 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.4/6.2 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.2 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 5.6/6.2 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 5.6/6.2 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 5.6/6.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 5.7/6.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 5.9/6.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 5.9/6.2 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  6.2/6.2 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 1.5 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/86.8 kB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 81.9/86.8 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 86.8/86.8 kB 612.4 kB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ------------ --------------------------- 163.8/536.2 kB 4.8 MB/s eta 0:00:01
#    ------------------ --------------------- 245.8/536.2 kB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 409.6/536.2 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  532.5/536.2 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 536.2/536.2 kB 2.4 MB/s eta 0:00:00
# Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.3 kB ? eta -:--:--
#    -------------------------------------- - 81.9/85.3 kB 4.8 MB/s eta 0:00:01
#    -------------------------------------- - 81.9/85.3 kB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 85.3/85.3 kB 536.2 kB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB 262.6 kB/s eta 0:00:11
#     --------------------------------------- 0.1/2.9 MB 409.6 kB/s eta 0:00:07
#    -- ------------------------------------- 0.2/2.9 MB 980.4 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.9 MB 1.4 MB/s eta 0:00:02
#    ------ --------------------------------- 0.5/2.9 MB 1.8 MB/s eta 0:00:02
#    --------- ------------------------------ 0.7/2.9 MB 2.2 MB/s eta 0:00:01
#    ------------ --------------------------- 0.9/2.9 MB 2.5 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.9 MB 2.6 MB/s eta 0:00:01
#    --------------- ------------------------ 1.1/2.9 MB 2.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.4/2.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.9 MB 3.0 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.9 MB 3.1 MB/s eta 0:00:01
#    --------------------------- ------------ 2.0/2.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------ --------- 2.2/2.9 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.5/2.9 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 2.7/2.9 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  2.9/2.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  2.9/2.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  2.9/2.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 3.0 MB/s eta 0:00:00
# Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
#    ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#    -------------------------------------- - 92.2/95.2 kB ? eta -:--:--
#    ---------------------------------------- 95.2/95.2 kB 1.8 MB/s eta 0:00:00
# Building wheels for collected packages: antlr4-python3-runtime, iopath
#   Building wheel for antlr4-python3-runtime (pyproject.toml): started
#   Building wheel for antlr4-python3-runtime (pyproject.toml): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144577 sha256=4d381752aff52e7e1842b2ffeeda2372f98a9e68a58e8cd9ec09c889c74b9de2
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\1f\be\48\13754633f1d08d1fbfc60d5e80ae1e5d7329500477685286cd
#   Building wheel for iopath (pyproject.toml): started
#   Building wheel for iopath (pyproject.toml): finished with status 'done'
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31542 sha256=f5fc5c92a5e3f97a0532fe5cdb20a4582968fb80669886ea6a38b575b9c08901
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\7c\96\04\4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built antlr4-python3-runtime iopath
# Installing collected packages: pyreadline3, mpmath, flatbuffers, antlr4-python3-runtime, unstructured.pytesseract, sympy, scipy, safetensors, python-multipart, pypdfium2, pyasn1, proto-plus, pdf2image, opencv-python, onnx, omegaconf, MarkupSafe, humanfriendly, googleapis-common-protos, Deprecated, cachetools, rsa, pyasn1-modules, pikepdf, jinja2, iopath, grpcio-status, coloredlogs, torch, tokenizers, pycocotools, pdfminer.six, onnxruntime, google-auth, transformers, torchvision, pdfplumber, google-api-core, timm, layoutparser, unstructured-inference, google-cloud-vision, effdet

# %%
pip install unstructured-inference
# Out:
# Collecting unstructured-inference
#   Using cached unstructured_inference-0.7.36-py3-none-any.whl.metadata (5.9 kB)
# Collecting layoutparser (from unstructured-inference)
#   Using cached layoutparser-0.3.4-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: python-multipart in .\venv\lib\site-packages (from unstructured-inference) (0.0.9)
# Requirement already satisfied: huggingface-hub in .\venv\lib\site-packages (from unstructured-inference) (0.24.5)
# Collecting opencv-python!=4.7.0.68 (from unstructured-inference)
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting onnx (from unstructured-inference)
#   Using cached onnx-1.16.2-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting onnxruntime>=1.17.0 (from unstructured-inference)
#   Using cached onnxruntime-1.18.1-cp312-cp312-win_amd64.whl.metadata (4.5 kB)
# Requirement already satisfied: matplotlib in .\venv\lib\site-packages (from unstructured-inference) (3.9.1)
# Collecting torch (from unstructured-inference)
#   Using cached torch-2.4.0-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting timm (from unstructured-inference)
#   Using cached timm-1.0.8-py3-none-any.whl.metadata (53 kB)
# Collecting transformers>=4.25.1 (from unstructured-inference)
#   Using cached transformers-4.43.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: rapidfuzz in .\venv\lib\site-packages (from unstructured-inference) (3.9.5)
# Collecting coloredlogs (from onnxruntime>=1.17.0->unstructured-inference)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in .\venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference) (24.3.25)
# Requirement already satisfied: numpy<2.0,>=1.21.6 in .\venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference) (1.26.4)
# Requirement already satisfied: packaging in .\venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference) (24.1)
# Requirement already satisfied: protobuf in .\venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference) (5.27.3)
# Requirement already satisfied: sympy in .\venv\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference) (1.13.1)
# Requirement already satisfied: filelock in .\venv\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (3.15.4)
# Requirement already satisfied: pyyaml>=5.1 in .\venv\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in .\venv\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (2024.7.24)
# Requirement already satisfied: requests in .\venv\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in .\venv\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (0.4.3)
# Collecting tokenizers<0.20,>=0.19 (from transformers>=4.25.1->unstructured-inference)
#   Using cached tokenizers-0.19.1-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: tqdm>=4.27 in .\venv\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (4.64.0)
# Requirement already satisfied: fsspec>=2023.5.0 in .\venv\lib\site-packages (from huggingface-hub->unstructured-inference) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in .\venv\lib\site-packages (from huggingface-hub->unstructured-inference) (4.12.2)
# Requirement already satisfied: scipy in .\venv\lib\site-packages (from layoutparser->unstructured-inference) (1.14.0)
# Requirement already satisfied: pandas in .\venv\lib\site-packages (from layoutparser->unstructured-inference) (2.2.2)
# Requirement already satisfied: pillow in .\venv\lib\site-packages (from layoutparser->unstructured-inference) (10.4.0)
# Collecting iopath (from layoutparser->unstructured-inference)
#   Using cached iopath-0.1.10-py3-none-any.whl
# Collecting pdfplumber (from layoutparser->unstructured-inference)
#   Using cached pdfplumber-0.11.2-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: pdf2image in .\venv\lib\site-packages (from layoutparser->unstructured-inference) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in .\venv\lib\site-packages (from matplotlib->unstructured-inference) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in .\venv\lib\site-packages (from matplotlib->unstructured-inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\venv\lib\site-packages (from matplotlib->unstructured-inference) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\venv\lib\site-packages (from matplotlib->unstructured-inference) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in .\venv\lib\site-packages (from matplotlib->unstructured-inference) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\venv\lib\site-packages (from matplotlib->unstructured-inference) (2.9.0.post0)
# Collecting torchvision (from timm->unstructured-inference)
#   Using cached torchvision-0.19.0-1-cp312-cp312-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: networkx in .\venv\lib\site-packages (from torch->unstructured-inference) (3.3)
# Collecting jinja2 (from torch->unstructured-inference)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: setuptools in .\venv\lib\site-packages (from torch->unstructured-inference) (72.1.0)
# Requirement already satisfied: six>=1.5 in .\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->unstructured-inference) (1.16.0)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from tqdm>=4.27->transformers>=4.25.1->unstructured-inference) (0.4.6)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: portalocker in .\venv\lib\site-packages (from iopath->layoutparser->unstructured-inference) (2.10.1)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->unstructured-inference)
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: pytz>=2020.1 in .\venv\lib\site-packages (from pandas->layoutparser->unstructured-inference) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in .\venv\lib\site-packages (from pandas->layoutparser->unstructured-inference) (2024.1)
# Collecting pdfminer.six==20231228 (from pdfplumber->layoutparser->unstructured-inference)
#   Using cached pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pypdfium2>=4.18.0 in .\venv\lib\site-packages (from pdfplumber->layoutparser->unstructured-inference) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in .\venv\lib\site-packages (from pdfminer.six==20231228->pdfplumber->layoutparser->unstructured-inference) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in .\venv\lib\site-packages (from pdfminer.six==20231228->pdfplumber->layoutparser->unstructured-inference) (43.0.0)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\lib\site-packages (from requests->transformers>=4.25.1->unstructured-inference) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\venv\lib\site-packages (from requests->transformers>=4.25.1->unstructured-inference) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in .\venv\lib\site-packages (from requests->transformers>=4.25.1->unstructured-inference) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\venv\lib\site-packages (from sympy->onnxruntime>=1.17.0->unstructured-inference) (1.3.0)
# Requirement already satisfied: pyreadline3 in .\venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.17.0->unstructured-inference) (3.4.1)
# Requirement already satisfied: pywin32>=226 in .\venv\lib\site-packages (from portalocker->iopath->layoutparser->unstructured-inference) (306)
# Requirement already satisfied: cffi>=1.12 in .\venv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser->unstructured-inference) (1.16.0)
# Requirement already satisfied: pycparser in .\venv\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser->unstructured-inference) (2.22)
# Using cached unstructured_inference-0.7.36-py3-none-any.whl (56 kB)
# Using cached onnxruntime-1.18.1-cp312-cp312-win_amd64.whl (5.6 MB)
# Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached transformers-4.43.3-py3-none-any.whl (9.4 MB)
# Using cached layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
# Using cached onnx-1.16.2-cp312-cp312-win_amd64.whl (14.4 MB)
# Using cached timm-1.0.8-py3-none-any.whl (2.3 MB)
# Using cached torch-2.4.0-cp312-cp312-win_amd64.whl (197.8 MB)
# Using cached tokenizers-0.19.1-cp312-none-win_amd64.whl (2.2 MB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached pdfplumber-0.11.2-py3-none-any.whl (58 kB)
# Using cached pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
# Using cached torchvision-0.19.0-1-cp312-cp312-win_amd64.whl (1.3 MB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Installing collected packages: opencv-python, onnx, MarkupSafe, humanfriendly, jinja2, iopath, coloredlogs, torch, tokenizers, pdfminer.six, onnxruntime, transformers, torchvision, pdfplumber, timm, layoutparser, unstructured-inference
#   Attempting uninstall: pdfminer.six
#     Found existing installation: pdfminer.six 20240706
#     Uninstalling pdfminer.six-20240706:
#       Successfully uninstalled pdfminer.six-20240706
# Successfully installed MarkupSafe-2.1.5 coloredlogs-15.0.1 humanfriendly-10.0 iopath-0.1.10 jinja2-3.1.4 layoutparser-0.3.4 onnx-1.16.2 onnxruntime-1.18.1 opencv-python-4.10.0.84 pdfminer.six-20231228 pdfplumber-0.11.2 timm-1.0.8 tokenizers-0.19.1 torch-2.4.0 torchvision-0.19.0 transformers-4.43.3 unstructured-inference-0.7.36
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip uninstall torch

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in .\venv\lib\site-packages (2.4.0)
# Requirement already satisfied: filelock in .\venv\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in .\venv\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in .\venv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in .\venv\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in .\venv\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in .\venv\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in .\venv\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\venv\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\venv\lib\site-packages (from sympy->torch) (1.3.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip uninstall torch torchvision torchaudio
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch==2.3.0 torchvision==0.18.0 torchaudio==2.3.0

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.4.0
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: D:\multivector+opensource_llm\venv\Lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, setuptools, sympy, typing-extensions
# Required-by: timm, torchvision, unstructured-inference

# %%
from unstructured.partition.pdf import partition_pdf

# Returns a List[Element] present in the pages of the parsed pdf document
elements = partition_pdf(filename="informa-plc---market-update.pdf",
                        strategy="auto",
                        infer_table_structure=True,
                        chunking_strategy="by_title",
                        max_characters=15000,
                        combine_text_under_n_chars=13000
                        )
# Out:
# Some weights of the model checkpoint at microsoft/table-transformer-structure-recognition were not used when initializing TableTransformerForObjectDetection: ['model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing TableTransformerForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TableTransformerForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
elements
# Out:
# [<unstructured.documents.elements.CompositeElement at 0x2103d612c90>,
#  <unstructured.documents.elements.Table at 0x2103d700080>,
#  <unstructured.documents.elements.CompositeElement at 0x2103876b920>,
#  <unstructured.documents.elements.Table at 0x2103d7000b0>,
#  <unstructured.documents.elements.CompositeElement at 0x2103d7019a0>]

# %%
tables = [el.text for el in elements if el.category == "Table"]
texts=[el.text for el in elements if el.category == "CompositeElement"]
texts
# Out:
# ['@) informa\n\nInforma LEI: 5493006VM2LKUPSEDU20\n\nInforma PLC: Press Release\n\n8 May 2024\n\nMarket Update\n\nContinuing momentum and growth\n\nInforma (LSE: INF.L), the international B2B Events, B2B Digital Services and Academic Markets Group, today issued an update on trading, key appointments and progress on its TechTarget combination.\n\nStephen A. Carter, Group Chief Executive, Informa, said:\n\n"All Informa’s businesses are performing ahead or in line with 2024 targets, delivering growth and momentum which sees us delivering at the upper end of guidance range. Consequently, we are increasing our 2024 share buyback program by c.50% to £500m. At the same time, we are strengthening our Leadership Team with key appointments, both in our Academic Markets business, as well as in the management of our Data, Brands and Intellectual Property.”\n\nHe concluded: "| am thrilled to
in connection with the proposed transaction. BEFORE MAKING ANY VOTING OR INVESTMENT DECISION, INVESTORS AND SECURITY HOLDERS OF TECHTARGET ARE URGED TO READ CAREFULLY AND IN THEIR) ENTIRETY THE PROXY STATEMENT/PROSPECTUS WHEN IT BECOMES AVAILABLE AND ANY OTHER RELEVANT DOCUMENTS THAT ARE FILED OR WILL BE FILED BY TECHTARGET OR NEWCO WITH THE SEC, AS WELL AS ANY AMENDMENTS OR SUPPLEMENTS TO THESE DOCUMENTS, IN CONNECTION WITH THE PROPOSED TRANSACTION, WHEN THEY BECOME AVAILABLE BECAUSE THESE DOCUMENTS CONTAIN OR WILL CONTAIN IMPORTANT INFORMATION ABOUT THE PROPOSED TRANSACTION AND RELATED MATTERS. TechTarget investors and security holders will be able to obtain free copies of the Proxy Statement/Prospectus (when they become available), as well as other filings containing important information about TechTarget, NewCo, and other parties to the proposed transaction (in ...

# %%
# !pip install --quiet langchain_experimental
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in .\venv\lib\site-packages (from sentence-transformers) (4.43.3)
# Requirement already satisfied: tqdm in .\venv\lib\site-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.11.0 in .\venv\lib\site-packages (from sentence-transformers) (2.4.0)
# Requirement already satisfied: numpy in .\venv\lib\site-packages (from sentence-transformers) (1.26.4)
# Collecting scikit-learn (from sentence-transformers)
#   Downloading scikit_learn-1.5.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: scipy in .\venv\lib\site-packages (from sentence-transformers) (1.14.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in .\venv\lib\site-packages (from sentence-transformers) (0.24.5)
# Requirement already satisfied: Pillow in .\venv\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in .\venv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in .\venv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in .\venv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in .\venv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in .\venv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in .\venv\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in .\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: networkx in .\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in .\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in .\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (72.1.0)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in .\venv\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in .\venv\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in .\venv\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in .\venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in .\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\venv\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\venv\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in .\venv\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\venv\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ---------------------------------------- 0.0/227.1 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/227.1 kB 660.6 kB/s eta 0:00:01
#    ----- --------------------------------- 30.7/227.1 kB 660.6 kB/s eta 0:00:01
#    ------------ -------------------------- 71.7/227.1 kB 563.7 kB/s eta 0:00:01
#    ------------------ ------------------- 112.6/227.1 kB 726.2 kB/s eta 0:00:01
#    -------------------- ----------------- 122.9/227.1 kB 554.9 kB/s eta 0:00:01
#    ----------------------------- -------- 174.1/227.1 kB 655.4 kB/s eta 0:00:01
#    ----------------------------- -------- 174.1/227.1 kB 655.4 kB/s eta 0:00:01
#    -------------------------------- ----- 194.6/227.1 kB 562.0 kB/s eta 0:00:01
#    -------------------------------------  225.3/227.1 kB 599.0 kB/s eta 0:00:01
#    -------------------------------------  225.3/227.1 kB 599.0 kB/s eta 0:00:01
#    -------------------------------------- 227.1/227.1 kB 478.7 kB/s eta 0:00:00
# Downloading scikit_learn-1.5.1-cp312-cp312-win_amd64.whl (10.9 MB)
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.9 MB 2.6 MB/s eta 0:00:05
#     --------------------------------------- 0.2/10.9 MB 2.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/10.9 MB 2.8 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/10.9 MB 2.7 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.9 MB 2.9 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.9 MB 2.3 MB/s eta 0:00:05
#    -- ------------------------------------- 0.8/10.9 MB 2.6 MB/s eta 0:00:04
#    --- ------------------------------------ 1.1/10.9 MB 3.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/10.9 MB 3.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/10.9 MB 3.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.7/10.9 MB 3.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.7/10.9 MB 3.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.7/10.9 MB 3.1 MB/s eta 0:00:03
#    ------ --------------------------------- 1.9/10.9 MB 3.0 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/10.9 MB 3.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.2/10.9 MB 3.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.3/10.9 MB 3.1 MB/s eta 0:00:03
#    --------- ------------------------------ 2.5/10.9 MB 3.1 MB/s eta 0:00:03
#    --------- ------------------------------ 2.7/10.9 MB 3.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.8/10.9 MB 3.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.8/10.9 MB 3.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/10.9 MB 2.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.0/10.9 MB 2.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.2/10.9 MB 3.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.2/10.9 MB 2.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.2/10.9 MB 2.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.3/10.9 MB 2.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/10.9 MB 2.6 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/10.9 MB 2.6 MB/s eta 0:00:03
#    ------------ --------------------------- 3.5/10.9 MB 2.5 MB/s eta 0:00:03
#    ------------- -------------------------- 3.6/10.9 MB 2.5 MB/s eta 0:00:03
#    ------------- -------------------------- 3.7/10.9 MB 2.5 MB/s eta 0:00:03
#    ------------- -------------------------- 3.8/10.9 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.9 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.9 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.9 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.9 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 4.0/10.9 MB 2.3 MB/s eta 0:00:04
#    -------------- ------------------------- 4.1/10.9 MB 2.3 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/10.9 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 4.3/10.9 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 4.3/10.9 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 4.3/10.9 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 4.4/10.9 MB 2.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.4/10.9 MB 2.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.5/10.9 MB 2.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.6/10.9 MB 2.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.8/10.9 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 5.0/10.9 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 5.2/10.9 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.3/10.9 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 5.4/10.9 MB 2.3 MB/s eta 0:00:03
#    -------------------- ------------------- 5.5/10.9 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 5.6/10.9 MB 2.3 MB/s eta 0:00:03
#    -------------------- ------------------- 5.7/10.9 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 5.8/10.9 MB 2.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.1/10.9 MB 2.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.2/10.9 MB 2.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.4/10.9 MB 2.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.5/10.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------ --------------- 6.6/10.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 6.9/10.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 7.0/10.9 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 7.3/10.9 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 7.5/10.9 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.7/10.9 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.8/10.9 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.1/10.9 MB 2.6 MB/s eta 0:00:02
#    ------------------------------ --------- 8.3/10.9 MB 2.6 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/10.9 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 8.6/10.9 MB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/10.9 MB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 9.0/10.9 MB 2.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.1/10.9 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/10.9 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 9.9/10.9 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.3/10.9 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 10.4/10.9 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  10.8/10.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  10.9/10.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  10.9/10.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  10.9/10.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.9/10.9 MB 2.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scikit-learn, sentence-transformers
# Successfully installed scikit-learn-1.5.1 sentence-transformers-3.0.1 threadpoolctl-3.5.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain.embeddings import HuggingFaceEmbeddings

model_name = "BAAI/bge-large-en-v1.5"
model_kwargs = {'device': 'cpu'}
embeddings = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
)
# Out:
# d:\multivector+opensource_llm\venv\Lib\site-packages\huggingface_hub\file_download.py:159: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\models--BAAI--bge-large-en-v1.5. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
import uuid
from langchain.schema import Document
from langchain_experimental.text_splitter import SemanticChunker

docs = [Document(page_content=text) for text in texts]
doc_ids = [str(uuid.uuid4()) for _ in docs]

id_key="doc_id"

# The splitter to use to create smaller chunks
child_text_splitter = SemanticChunker(embeddings=embeddings)
sub_docs = []
for i, doc in enumerate(docs):
    _id = doc_ids[i]
    _sub_docs = child_text_splitter.split_documents([doc])
    for _doc in _sub_docs:
        _doc.metadata[id_key] = _id
    sub_docs.extend(_sub_docs)

# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
summary_texts = [
    Document(page_content=s, metadata={id_key: doc_ids[i]})
    for i, s in enumerate(texts)
]
summary_texts
# Out:
# [Document(metadata={'doc_id': '70558ca8-86e2-48a1-a7cc-37fab8268893'}, page_content='@) informa\n\nInforma LEI: 5493006VM2LKUPSEDU20\n\nInforma PLC: Press Release\n\n8 May 2024\n\nMarket Update\n\nContinuing momentum and growth\n\nInforma (LSE: INF.L), the international B2B Events, B2B Digital Services and Academic Markets Group, today issued an update on trading, key appointments and progress on its TechTarget combination.\n\nStephen A. Carter, Group Chief Executive, Informa, said:\n\n"All Informa’s businesses are performing ahead or in line with 2024 targets, delivering growth and momentum which sees us delivering at the upper end of guidance range. Consequently, we are increasing our 2024 share buyback program by c.50% to £500m. At the same time, we are strengthening our Leadership Team with key appointments, both in our Academic Markets business, as well as in the management of our Data, Brands and Intellectual Property.”\n\nHe concluded: "| am thrilled to see Executives of Penny and Jill\'s quality and experience joining the leadership team at Informa. Our business is in growth, it is expanding, and we see lots of opportunities ahead. | am convinced they will help us get there faster and capture more of them.”\n\nHighlights\n\ne Strong operating performance...All businesses delivering ahead of or in line with 2024 targets; we are now performing to the upper end of market guidance on revenues, adjusted operating profit and free cash flow;\n\ne Executive appointments:\n\no Taylor & Francis Chief Executive...Penny Ladkin-Brand joins the Informa Leadership Team as the Chief Executive of Taylor & Francis; bringing extensive experience of specialist publishing, online platforms and digital acceleration;\n\no Group Chief Marketing Officer... Jill Dougan joins the Informa Leadership Team in the newly created role of Group Chief Marketing Officer to create further value from Informa’s extensive Brand portfolio, Intellectual Property and growing First Party Data;\n\ne\n\nTechTarget combination progress...Proposed creation of NASDAQ-listed New TechTarget, as a Leading B2B Growth Accelerator for Technology companies, on track for Q4 2024;\n\ne Accelerating Shareholder Returns... 2024 share buyback programme increased to £500m, expanded by a further £160m;\n\ne Al Partnership and Data Access Agreement...Non-exclusive agreement signed with Microsoft, including Access to Advanced Learning content and data, and a Partnership to explore Al expert applications.\n\nMarket Guidance\n\n2024 Updated Guidance 2024 Current Guidance\n\n2023 Reported'),
#  Document(metadata={'doc_id': '7eed2afe-82de-4967-b79e-87c0ef77b051'}, page_content='About TechTarget\n\nTechTarget (NASDAQ: TTGT) is the global leader in purchase intent-driven marketing and sales services that deliver business impact for enterprise technology companies. By creating abundant, high-quality editorial content across approximately 150 websites and 1,000 webinars and virtual event channels, TechTarget attracts and nurtures communities of technology buyers researching their companies’ information echnology needs. By understanding these buyers’ content consumption behaviours, TechTarget creates he purchase intent insights that fuel efficient and effective marketing and sales activities for clients around he world.\n\nTechTarget has offices in Boston, London, Munich, New York, Paris, Singapore and Sydney. For more information, visit techtarget.com and follow us on Twitter @TechTarget.\n\nn 2023, TechTarget reported revenue of $230m and income before provision for income taxes of $14.4m. ts reported gross assets at 31 December 2023 were $699.9m.\n\nAbout Informa Tech\n\nnforma Tech is a leading provider of market insight and market access to the global business technology community. Through in-depth expertise and an engaged audience community, Informa Tech helps business professionals make better technology decisions and marketers reach the most powerful tech buyers and influencers in the world. Across its portfolio of over 100+ trusted brands, Informa Tech has over 1000 industry experts, including over 400 research analysts and consultants in global research group Ormdia, and a monthly audience reach of over 125 million. Informa Tech is a division of FTSE 100 company Informa plc. For more information, visit informatech.com\n\nThe digital businesses of Informa Tech being combined with TechTarget include Industry Dive (Specialis B2B Content/Brands), Omdia (Specialist Tech Research), NetLine (Demand Generation and Buyer Intent), and other Specialist Tech Digital Media Brands (eg Information Week, Light Reading, Heavy Reading, A\\ Business).\n\nIn 2022, these digital businesses delivered revenue of £220.7m and statutory profit before tax, pos exceptional and amortisation costs of £2.9m.\n\nAdditional Information and Where to Find It\n\nIn connection with the proposed transaction (the “proposed transaction”) between Informa and TechTarget, TechTarget CombineCo, Inc. (‘NewCo" or, after the completion of the proposed transaction, “New TechTarget”) and TechTarget will prepare and file relevant materials with the Securities and Exchange\n\n4 Informa PLC | Market Update\n\n(Oj informa\n\nCommission (the “SEC’), including a registration statement on Form S-4 that will contain a proxy statemen of TechTarget that also constitutes a prospectus of NewCo (the “Proxy Statement/Prospectus’). A definitive Proxy Statement/Prospectus will be mailed to stockholders of TechTarget. TechTarget and NewCo may also ile other documents with the SEC regarding the proposed transaction. This communication is not a substitute for any proxy statement, registration statement or prospectus, or any other document tha TechTarget or NewCo (as applicable) may file with the SEC in connection with the proposed transaction. BEFORE MAKING ANY VOTING OR INVESTMENT DECISION, INVESTORS AND SECURITY HOLDERS OF TECHTARGET ARE URGED TO READ CAREFULLY AND IN THEIR) ENTIRETY THE PROXY STATEMENT/PROSPECTUS WHEN IT BECOMES AVAILABLE AND ANY OTHER RELEVANT DOCUMENTS THAT ARE FILED OR WILL BE FILED BY TECHTARGET OR NEWCO WITH THE SEC, AS WELL AS ANY AMENDMENTS OR SUPPLEMENTS TO THESE DOCUMENTS, IN CONNECTION WITH THE PROPOSED TRANSACTION, WHEN THEY BECOME AVAILABLE BECAUSE THESE DOCUMENTS CONTAIN OR WILL CONTAIN IMPORTANT INFORMATION ABOUT THE PROPOSED TRANSACTION AND RELATED MATTERS. TechTarget investors and security holders will be able to obtain free copies of the Proxy Statement/Prospectus (when they become available), as well as other filings containing important inf ...

# %%
from langchain_qdrant import QdrantVectorStore
import os
from dotenv import load_dotenv

load_dotenv()


vectorstore = QdrantVectorStore.from_documents(
    documents=sub_docs,
    embedding=embeddings,
    collection_name="doc_store_new",
    url=os.environ.get('QDRANT_URL'), 
    api_key=os.environ.get('QDRANT_API_KEY'),
)

# %%
len(docs)
# Out:
# 3

# %%
len(sub_docs)
# Out:
# 9

# %%
docs
# Out:
# [Document(page_content='@) informa\n\nInforma LEI: 5493006VM2LKUPSEDU20\n\nInforma PLC: Press Release\n\n8 May 2024\n\nMarket Update\n\nContinuing momentum and growth\n\nInforma (LSE: INF.L), the international B2B Events, B2B Digital Services and Academic Markets Group, today issued an update on trading, key appointments and progress on its TechTarget combination.\n\nStephen A. Carter, Group Chief Executive, Informa, said:\n\n"All Informa’s businesses are performing ahead or in line with 2024 targets, delivering growth and momentum which sees us delivering at the upper end of guidance range. Consequently, we are increasing our 2024 share buyback program by c.50% to £500m. At the same time, we are strengthening our Leadership Team with key appointments, both in our Academic Markets business, as well as in the management of our Data, Brands and Intellectual Property.”\n\nHe concluded: "| am thrilled to see Executives of Penny and Jill\'s quality and experience joining the leadership team at Informa. Our business is in growth, it is expanding, and we see lots of opportunities ahead. | am convinced they will help us get there faster and capture more of them.”\n\nHighlights\n\ne Strong operating performance...All businesses delivering ahead of or in line with 2024 targets; we are now performing to the upper end of market guidance on revenues, adjusted operating profit and free cash flow;\n\ne Executive appointments:\n\no Taylor & Francis Chief Executive...Penny Ladkin-Brand joins the Informa Leadership Team as the Chief Executive of Taylor & Francis; bringing extensive experience of specialist publishing, online platforms and digital acceleration;\n\no Group Chief Marketing Officer... Jill Dougan joins the Informa Leadership Team in the newly created role of Group Chief Marketing Officer to create further value from Informa’s extensive Brand portfolio, Intellectual Property and growing First Party Data;\n\ne\n\nTechTarget combination progress...Proposed creation of NASDAQ-listed New TechTarget, as a Leading B2B Growth Accelerator for Technology companies, on track for Q4 2024;\n\ne Accelerating Shareholder Returns... 2024 share buyback programme increased to £500m, expanded by a further £160m;\n\ne Al Partnership and Data Access Agreement...Non-exclusive agreement signed with Microsoft, including Access to Advanced Learning content and data, and a Partnership to explore Al expert applications.\n\nMarket Guidance\n\n2024 Updated Guidance 2024 Current Guidance\n\n2023 Reported'),
#  Document(page_content='*Guidance excludes any effect of the proposed combination with TechTarget; GBP/USD 1.25\n\n1\n\nInforma PLC | Market Update\n\nO informa\n\nStrong Operating Performance\n\nThe Informa Group has continued to deliver strong performances through the first four months of the year, with underlying revenue growth across both B2B Markets (Informa Markets, Informa Connect and Informa Tech) and Academic Markets in line or ahead of our expectations.\n\nMomentum is strong across all major geographic regions, including North America, Asia and IMEA (India, Middle East & Africa), with notable performances in B2B Markets in Healthcare (Arab Health), Manufacturing (IME West), Technology (LEAP), Real Estate & Construction (World of Concrete) and Aviation (MRO Americas), amongst others.\n\nOur first major B2B brand that traded in Mainland China in 2024 was in Hospitality & Food in April (Hotelex Shanghai & Expo Food), delivering healthy year-on-year growth, and our major Beauty brand (China Beauty) in May is tracking to plan.\n\ney 2023 portfolio additions (Tarsus, Winsight, HIMSS) are contributing as planned to our momentum and growth. The flagship HIMSS healthcare technology brand took place in March, delivering attendee and exhibitor growth, and the major Food Services brand (National Restaurant Association Show) is similarly on rack to deliver strong year-on-year growth in May.\n\nn Academic
ading, Heavy Reading, A\\ Business).\n\nIn 2022, these digital businesses delivered revenue of £220.7m and statutory profit before tax, pos exceptional and amortisation costs of £2.9m.\n\nAdditional Information and Where to Find It\n\nIn connection with the proposed transaction (the “proposed transaction”) between Informa and TechTarget, TechTarget CombineCo, Inc. (‘NewCo" or, after the completion of the proposed transaction, “New TechTarget”) and TechTarget will prepare and file relevant materials with the Securities and Exchange\n\n4 Informa PLC | Market Update\n\n(Oj informa\n\nCommission (the “SEC’), including a registration statement on Form S-4 that will contain a proxy statemen of TechTarget that also constitutes a prospectus of NewCo (the “Proxy Statement/Prospectus’). A definitive Proxy Statement/Prospectus will be mailed to stockholders of TechTarget. TechTarget and NewCo may also ile other documents with the SEC regarding the proposed transaction. This communication is not a substitute for any proxy statement, registration statement or prospectus, or any other document tha TechTarget or NewCo (as applicable) may file with the SEC in connection with the proposed transaction. BEFORE MAKING ANY VOTING OR INVESTMENT DECISION, INVESTORS AND SECURITY HOLDERS OF TECHTARGET ARE URGED TO READ CAREFULLY AND IN THEIR) ENTIRETY THE PROXY STATEMENT/PROSPECTUS WHEN IT BECOMES AVAILABLE AND ANY OTHER RELEVANT DOCUMENTS THAT ARE FILED OR WILL BE FILED BY TECHTARGET OR NEWCO WITH THE SEC, AS WELL AS ANY AMENDMENTS OR SUPPLEMENTS TO THESE DOCUMENTS, IN CONNECTION WITH THE PROPOSED TRANSACTION, WHEN THEY BECOME AVAILABLE BECAUSE THESE DOCUMENTS CONTAIN OR WILL CONTAIN IMPORTANT INFORMATION ABOUT THE PROPOSED TRANSACTION AND RELATED MATTERS. TechTarget investors and security holders will be able to obtain free copies of the Proxy Statement/Prospectus (when they become available), as well as other filings containing important information about TechTarget, NewCo, and other parties to the pr ...

# %%
from langchain.storage import InMemoryStore

docstore = InMemoryStore()

# %%
from langchain.retrievers.multi_vector import MultiVectorRetriever

retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    byte_store=docstore,
    id_key=id_key,
    search_kwargs={"k": 10}
)

# %%
retriever.docstore.mset(list(zip(doc_ids, docs)))

# %%
retriever.vectorstore.add_documents(sub_docs)
# Out:
# ['0f3e5d8512fb49af813f00f824043428',
#  '842cf037d84d47b2b5bb532b9a46f51a',
#  '7e9ff2636a5e446c92e441fe145b5585',
#  'ae24179eef1143e3a1cefc79f90a48dd',
#  'ffa4bef9d8944ac78008cab6ce69ef8b',
#  'e816945b8dac4bfb82cc3deeaff83ccd',
#  '325f1089c50d4ef5a5550ea2b1641fd5',
#  '337a50d182354c7c819161802e7ba6e6',
#  'bd7773c2465543da9ec528183241152c']

# %%
# !pip install ollama
# Out:
# Collecting ollama
#   Downloading ollama-0.3.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in .\venv\lib\site-packages (from ollama) (0.27.0)
# Requirement already satisfied: anyio in .\venv\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (4.4.0)
# Requirement already satisfied: certifi in .\venv\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in .\venv\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.5)
# Requirement already satisfied: idna in .\venv\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.7)
# Requirement already satisfied: sniffio in .\venv\lib\site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in .\venv\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# Downloading ollama-0.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.3.1
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install -qU langchain-ollama
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain.prompts import ChatPromptTemplate
from langchain_ollama import ChatOllama
from langchain.schema.output_parser import StrOutputParser

prompt_text = """
<|begin_of_text|><|start_header_id|>system<|end_header_id|>
You are an assistant tasked with summarizing tables. 
Give a concise summary of the table chunk. Table chunk: 
{element} 

<|eot_id|><|start_header_id|>assistant<|end_header_id|> 
"""
prompt = ChatPromptTemplate.from_template(prompt_text)

# Summary chain
model = ChatOllama(
                model="llama3.1:8b",
                num_gpu=-1,
                num_ctx=512,
                num_thread=4,  # Adjust based on your CPU
                num_predict=64,
                f16_kv=True)
summarize_chain = {"element": lambda x: x} | prompt | model | StrOutputParser()

# %%
table_summaries = summarize_chain.batch(tables, {"max_concurrency": 5})
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 table_summaries = summarize_chain.batch(tables, {"max_concurrency": 5})
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_core\runnables\base.py:3023, in RunnableSequence.batch(self, inputs, config, return_exceptions, **kwargs)
#    3021     else:
#    3022         for i, step in enumerate(self.steps):
# -> 3023             inputs = step.batch(
#    3024                 inputs,
#    3025                 [
#    3026                     # each step a child run of the corresponding root run
#    3027                     patch_config(
#    3028                         config, callbacks=rm.get_child(f"seq:step:{i+1}")
#    3029                     )
#    3030                     for rm, config in zip(run_managers, configs)
#    3031                 ],
#    3032                 return_exceptions=return_exceptions,
#    3033                 **(kwargs if i == 0 else {}),
#    3034             )
#    3036 # finish the root runs
#    3037 except BaseException as e:
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_core\runnables\base.py:648, in Runnable.batch(self, inputs, config, return_exceptions, **kwargs)
#     645     return cast(List[Output], [invoke(inputs[0], configs[0])])
#     647 with get_executor_for_config(configs[0]) as executor:
# --> 648     return cast(List[Output], list(executor.map(invoke, inputs, configs)))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_core\runnables\config.py:528, in ContextThreadPoolExecutor.map.<locals>._wrapped_fn(*args)
#     527 def _wrapped_fn(*args: Any) -> T:
# --> 528     return contexts.pop().run(fn, *args)
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_core\runnables\base.py:641, in Runnable.batch.<locals>.invoke(input, config)
#     639         return e
#     640 else:
# --> 641     return self.invoke(input, config, **kwargs)
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:276, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     265 def invoke(
#     266     self,
#     267     input: LanguageModelInput,
#    (...)
#     271     **kwargs: Any,
#     272 ) -> BaseMessage:
#     273     config = ensure_config(config)
#     274     return cast(
#     275         ChatGeneration,
# --> 276         self.generate_prompt(
#     277             [self._convert_input(input)],
#     278             stop=stop,
#     279             callbacks=config.get("callbacks"),
#     280             tags=config.get("tags"),
#     281             metadata=config.get("metadata"),
#     282             run_name=config.get("run_name"),
#     283             run_id=config.pop("run_id", None),
#     284             **kwargs,
#     285         ).generations[0][0],
#     286     ).message
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:776, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     768 def generate_prompt(
#     769     self,
#     770     prompts: List[PromptValue],
#    (...)
#     773     **kwargs: Any,
#     774 ) -> LLMResult:
#     775     prompt_messages = [p.to_messages() for p in prompts]
# --> 776     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     631         if run_managers:
#     632             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 633         raise e
#     634 flattened_outputs = [
#     635     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     636     for res in results
#     637 ]
#     638 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:623, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     620 for i, m in enumerate(messages):
#     621     try:
#     622         results.append(
# --> 623             self._generate_with_cache(
#     624                 m,
#     625                 stop=stop,
#     626                 run_manager=run_managers[i] if run_managers else None,
#     627                 **kwargs,
#     628             )
#     629         )
#     630     except BaseException as e:
#     631         if run_managers:
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:845, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     843 else:
#     844     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 845         result = self._generate(
#     846             messages, stop=stop, run_manager=run_manager, **kwargs
#     847         )
#     848     else:
#     849         result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_ollama\chat_models.py:617, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     610 def _generate(
#     611     self,
#     612     messages: List[BaseMessage],
#    (...)
#     615     **kwargs: Any,
#     616 ) -> ChatResult:
# --> 617     final_chunk = self._chat_stream_with_aggregation(
#     618         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     619     )
#     620     generation_info = final_chunk.generation_info
#     621     chat_generation = ChatGeneration(
#     622         message=AIMessage(
#     623             content=final_chunk.text,
#    (...)
#     627         generation_info=generation_info,
#     628     )
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_ollama\chat_models.py:518, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     509 def _chat_stream_with_aggregation(
#     510     self,
#     511     messages: List[BaseMessage],
#    (...)
#     515     **kwargs: Any,
#     516 ) -> ChatGenerationChunk:
#     517     final_chunk = None
# --> 518     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     519         if not isinstance(stream_resp, str):
#     520             chunk = ChatGenerationChunk(
#     521                 message=AIMessageChunk(
#     522                     content=(
#    (...)
#     535                 ),
#     536             )
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\langchain_ollama\chat_models.py:500, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     490     yield Client(host=self.base_url).chat(
#     491         model=params["model"],
#     492         messages=ollama_messages,
#    (...)
#     497         tools=kwargs["tools"],
#     498     )
#     499 else:
# --> 500     yield from Client(host=self.base_url).chat(
#     501         model=params["model"],
#     502         messages=ollama_messages,
#     503         stream=True,
#     504         options=Options(**params["options"]),
#     505         keep_alive=params["keep_alive"],
#     506         format=params["format"],
#     507     )
#
# File d:\multivector+opensource_llm\venv\Lib\site-packages\ollama\_client.py:84, in Client._stream(self, method, url, **kwargs)
#      82 except httpx.HTTPStatusError as e:
#      83   e.response.read()
# ---> 84   raise ResponseError(e.response.text, e.response.status_code) from None
#      86 for line in r.iter_lines():
#      87   partial = json.loads(line)
#
# ResponseError: model requires more system memory (5.1 GiB) than is available (3.8 GiB)

# %%
table_ids = [str(uuid.uuid4()) for _ in tables]
summary_tables = [
    Document(page_content=s, metadata={id_key: table_ids[i]})
    for i, s in enumerate(table_summaries)
]
retriever.vectorstore.add_documents(summary_tables)
retriever.docstore.mset(list(zip(table_ids, tables)))

# %%
from langchain_core.runnables import RunnablePassthrough

# Prompt template
template = """Answer the question based only on the following context, which can include text and tables:
{context}
Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

# LLM
model = ChatOllama(model="llama3.1:8b",
                num_gpu=-1,
                num_ctx=512,
                num_thread=4,  # Adjust based on your CPU
                num_predict=64,
                f16_kv=True)

# RAG pipeline
chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

# %%
chain.invoke("Academic Markets Underlying Revenue Growth for the year 2024")
